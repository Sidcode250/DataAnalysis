# %%
'''import nw_module

nw_module.skill_list

nw_module.add(4,5)'''
# Out:
# 'import nw_module\n\nnw_module.skill_list\n\nnw_module.add(4,5)'

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = '$', ):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol

    self.total_salary = self.base_salary * (1 + self.bonus_rate)
    self.bonus = self.total_salary - self.base_salary

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.2f}'

  def Total(self):
    return f'{self.symbol}{self.total_salary:,.2f}'

  def Bonus(self):
    return f'{self.symbol}{self.bonus:,.2f}'

# %%
salary = BaseSalary(100000,0.2)
salary
# Out:
# $100,000.00

# %%
salary.Total()
# Out:
# '$120,000.00'

# %%
salary.Bonus()
# Out:
# '$20,000.00'

# %%
import numpy as np

job_titles1 = np.array(['A','B','C','D'])
salary1 = np.array([100,200,300,400])
bonus1 = np.array([01.,0.2,0.3,0.4])

total_salary1 = salary1 * (1 + bonus1)
print(total_salary1)

print(np.mean(total_salary1))
# Out:
# [200. 240. 390. 560.]
# 347.5

# %%
job_titles2 = np.array(['A','B','C','D','E'])
salary2 = np.array([100,200,300,400, np.nan])
bonus2 = np.array([01.,0.2,0.3,0.4, np.nan])

total_salary2 = salary1 * (1 + bonus1)
print(total_salary2)

print(np.nanmean(total_salary2))
# Out:
# [200. 240. 390. 560.]
# 347.5

# %%
# !pip install datasets
# Out:
# ^C

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.iloc[10:20, 0:2]
# Out:
#          job_title_short                                    job_title
# 10         Data Engineer         Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                Data Engineer
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13  Senior Data Engineer                         Senior Data Engineer
# 14         Data Engineer                                Data Engineer
# 15         Data Engineer                                Data Engineer
# 16         Data Engineer                            Big Data Engineer
# 17        Data Scientist                       Data Science Team Lead
# 18          Data Analyst                                 Data Analyst
# 19        Data Scientist                               Data Scientist

# %%
df[['job_title_short', 'job_title']].iloc[90:100]
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
